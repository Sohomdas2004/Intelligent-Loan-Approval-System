# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.impute import SimpleImputer

# %%
df=pd.read_csv("/content/LoanApprovalPrediction.csv")

# %%
df.head()
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0  LP001002   Male      No         0.0      Graduate            No
# 1  LP001003   Male     Yes         1.0      Graduate            No
# 2  LP001005   Male     Yes         0.0      Graduate           Yes
# 3  LP001006   Male     Yes         0.0  Not Graduate            No
# 4  LP001008   Male      No         0.0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
df["Dependents"] = (
    df["Dependents"]
    .replace("3+", 3)
)

# %%
x=df.drop(["Loan_ID","Loan_Status"],axis=1)
y = df["Loan_Status"]

# %%
x.head()
# Out:
#   Gender Married  Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male      No         0.0      Graduate            No             5849
# 1   Male     Yes         1.0      Graduate            No             4583
# 2   Male     Yes         0.0      Graduate           Yes             3000
# 3   Male     Yes         0.0  Not Graduate            No             2583
# 4   Male      No         0.0      Graduate            No             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0         NaN             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#   Property_Area
# 0         Urban
# 1         Rural
# 2         Urban
# 3         Urban
# 4         Urban

# %%
y.head()
# Out:
# 0    Y
# 1    N
# 2    Y
# 3    Y
# 4    Y
# Name: Loan_Status, dtype: object

# %%
y = y.map({
    "Y": 1,
    "N": 0
})

# Y → 1  (Approved)
# N → 0  (Rejected)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    x,
    y,
    test_size=0.2,
    random_state=42,
    stratify=y
)

# %%
X_train
# Out:
#      Gender Married  Dependents     Education Self_Employed  ApplicantIncome  \
# 27     Male      No         0.0  Not Graduate            No             1442
# 443    Male     Yes         0.0      Graduate            No             3948
# 127    Male      No         0.0      Graduate           Yes            20166
# 400    Male     Yes         1.0      Graduate            No             8300
# 279    Male      No         0.0      Graduate            No             3158
# ..      ...     ...         ...           ...           ...              ...
# 486    Male     Yes         1.0      Graduate           Yes             2895
# 38     Male      No         0.0  Not Graduate            No             3748
# 331  Female      No         0.0      Graduate            No             4160
# 30     Male      No         0.0      Graduate            No             3167
# 396  Female      No         0.0      Graduate           Yes             7441
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 27                 0.0        35.0             360.0             1.0
# 443             1733.0       149.0             360.0             0.0
# 127                0.0       650.0             480.0             NaN
# 400                0.0       152.0             300.0             0.0
# 279             3053.0        89.0             360.0             1.0
# ..                 ...         ...               ...             ...
# 486                0.0        95.0             360.0             1.0
# 38              1668.0       110.0             360.0             1.0
# 331                0.0        71.0             360.0             1.0
# 30                 0.0        74.0             360.0             1.0
# 396                0.0       194.0             360.0             1.0
#
#     Property_Area
# 27          Urban
# 443         Rural
# 127         Urban
# 400     Semiurban
# 279         Rural
# ..            ...
# 486     Semiurban
# 38      Semiurban
# 331     Semiurban
# 30          Urban
# 396         Rural
#
# [478 rows x 11 columns]

# %%
X_test
# Out:
#      Gender Married  Dependents Education Self_Employed  ApplicantIncome  \
# 562    Male     Yes         2.0  Graduate            No             3159
# 577    Male     Yes         0.0  Graduate            No             3859
# 545    Male     Yes         0.0  Graduate            No             3887
# 555  Female      No         0.0  Graduate            No             2378
# 222    Male     Yes         2.0  Graduate            No             6250
# ..      ...     ...         ...       ...           ...              ...
# 289    Male     Yes         3.0  Graduate           Yes             4416
# 472    Male     Yes         2.0  Graduate            No             8333
# 213    Male     Yes         2.0  Graduate           Yes             5000
# 193  Female     Yes         0.0  Graduate            No             3416
# 376    Male     Yes         2.0  Graduate            No             4566
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 562              461.0       108.0              84.0             1.0
# 577             3300.0       142.0             180.0             1.0
# 545             2669.0       162.0             360.0             1.0
# 555                0.0         9.0             360.0             1.0
# 222             1695.0       210.0             360.0             1.0
# ..                 ...         ...               ...             ...
# 289             1250.0       110.0             360.0             1.0
# 472                0.0       246.0             360.0             1.0
# 213                0.0        72.0             360.0             0.0
# 193             2816.0       113.0             360.0             NaN
# 376                0.0       100.0             360.0             1.0
#
#     Property_Area
# 562         Urban
# 577         Rural
# 545     Semiurban
# 555         Urban
# 222     Semiurban
# ..            ...
# 289         Urban
# 472     Semiurban
# 213     Semiurban
# 193     Semiurban
# 376         Urban
#
# [120 rows x 11 columns]

# %%
X_train.to_csv("x_train")

# %%
X_test.to_csv("x_test")

# %%
y_train.to_csv("y_train")

# %%
y_test.to_csv("y_test")
